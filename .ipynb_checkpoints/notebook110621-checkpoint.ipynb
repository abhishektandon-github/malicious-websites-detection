# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression, PassiveAggressiveClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
import warnings
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
def analyse(df, string):

    X_train, X_test, y_train, y_test = train_test_split(df, target, test_size = 0.20, random_state = 25)

    print("Accuracy for: ",string)

    # RandomForestClassifier
    model = RandomForestClassifier()

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    print("RandomForestClassifier:", accuracy_score(y_pred, y_test))

    # Decision Tree

    model = DecisionTreeClassifier()

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    print("DecisionTreeClassifier:", accuracy_score(y_pred, y_test),'\n')
    
    model = KNeighborsClassifier(n_neighbors=5)
    
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    print("KNNClassifier:", accuracy_score(y_pred, y_test),'\n')
    

    # # SVM
    # model = SVC(gamma=0.01)

    # model.fit(X_train, y_train)

    # y_pred = model.predict(X_test)

    # print("SVM:", accuracy_score(y_pred, y_test))

# %%
# load dataset
df = pd.read_csv('C:/Users/user/Desktop/project/dataset.csv')

# ip and target (numpy arrays)
df_ip = df['IP'].values
target = df['target'].values

# separate the 4 octets
arr = np.array(list(map(lambda x: x.split('.'), df_ip))).astype(np.int)

# convert numpy array `arr` to pandas DataFrame
new_df = pd.DataFrame(data = arr, columns = ['X1', 'X2', 'X3', 'X4'])

# ---- Feature Extraction ----

# Adding new features according to Octet Method
new_df['N2'] = 256 + new_df['X2']
new_df['N3'] = 512 + new_df['X3']
new_df['N4'] = 768 + new_df['X4']

# Additional features according to Ex-Octet Method
new_df['N5'] = 768 + (new_df['X1']+new_df['X2'])%256
new_df['N6'] = 1024 + (new_df['X1']+new_df['X2']+new_df['X3'])%256
new_df['N7'] = 1280 + (new_df['X1']+new_df['X2']+new_df['X3']+new_df['X4'])%256
new_df['target'] = df['target']


# final dataframe used for train/test

df0 = new_df[['X1']].values
df1 = new_df[['X1', 'N2']].values
df2 = new_df[['X1', 'N2', 'N3']].values
df3 = new_df[['X1', 'N2', 'N3', 'N4']].values
df4 = new_df[['X1', 'N2', 'N3', 'N4', 'N5']].values
df5 = new_df[['X1', 'N2', 'N3', 'N4', 'N5', 'N6']].values
df6 = new_df[['X1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7']].values

df7 = new_df[['X1', 'X2']].values
df8 = new_df[['X1', 'X2', 'X3']].values
df9 = new_df[['X1', 'X2', 'X3', 'X4']].values

df10 = new_df[['X1', 'X2', 'N2']].values
df11 = new_df[['X1', 'X2', 'N3']].values
df12 = new_df[['X1', 'X2', 'N4']].values
df13 = new_df[['X1', 'X2', 'N2', 'N3']].values
df14 = new_df[['X1', 'X2', 'N2', 'N3', 'N4']].values

df15 = new_df[['X1', 'X2', 'X3', 'N2', 'N3']].values

df16 = new_df[['N2']].values
df17 = new_df[['N2', 'N3']].values
df18 = new_df[['N2', 'N3', 'N4']].values
df19 = new_df[['N2', 'N3', 'N4', 'N5']].values
df20 = new_df[['N2', 'N3', 'N4', 'N5', 'N6']].values

df21 = new_df[['N3']].values
df22 = new_df[['N3', 'N4']].values
df23 = new_df[['N3', 'N4', 'N5']].values
df24 = new_df[['N3', 'N4', 'N5', 'N6']].values

df25 = new_df[['N5', 'N6']].values
df26 = new_df[['N4', 'N5', 'N6']].values

df27 = new_df[['X1', 'X2', 'N5']].values
df28 = new_df[['X1', 'X2', 'N6']].values
df29 = new_df[['X1', 'X2', 'N7']].values

df30 = new_df[['X1', 'X2', 'X3', 'N6']].values
df31 = new_df[['X1', 'X2', 'X3', 'X4', 'N7']].values

df32 = new_df[['X1', 'N2', 'N5']].values
df33 = new_df[['X1', 'N2', 'N6']].values
df34 = new_df[['X1', 'N2', 'N7']].values

df35 = new_df[['X1', 'N2', 'N3', 'N6']].values
df36 = new_df[['X1', 'N2', 'N3', 'N4', 'N7']].values

# %%
analyse(df0, 'X1')
analyse(df1, 'X1, N2')
analyse(df2, 'X1, N2, N3')
analyse(df3, 'X1, N2, N3, N4')
analyse(df4, 'X1, N2, N3, N4, N5')
analyse(df5, 'X1, N2, N3, N4, N5, N6')
analyse(df6, 'X1, N2, N3, N4, N5, N6, N7')

analyse(df7, 'X1, X2') # gives best results
analyse(df8, 'X1, X2, X3')
analyse(df9, 'X1, X2, X3, X4')

analyse(df10, 'X1, X2, N2')
analyse(df11, 'X1, X2, N3')
analyse(df12, 'X1, X2, N4')
analyse(df13, 'X1, X2, N2, N3')
analyse(df14, 'X1, X2, N2, N3, N4')

analyse(df15, 'X1, X2, X3, N2, N3')

analyse(df16, 'N2')
analyse(df17, 'N2, N3')
analyse(df18, 'N2, N3, N4')
analyse(df19, 'N2, N3, N4, N5')
analyse(df20, 'N2, N3, N4, N5, N6')


analyse(df21, 'N3')
analyse(df22, 'N3, N4')
analyse(df23, 'N3, N4, N5')
analyse(df24, 'N3, N4, N5, N6')

analyse(df25, 'N5, N6')
analyse(df26, 'N4, N5, N6')

analyse(df27, 'X1, X2, N5') #gives best results
analyse(df28, 'X1, X2, N6')
analyse(df29, 'X1, X2, N7')

analyse(df30, 'X1, X2, X3, N6')
analyse(df31, 'X1, X2, X3, X4, N7')

analyse(df32, 'X1, N2, N5')
analyse(df33, 'X1, N2, N6')
analyse(df34, 'X1, N2, N7')

analyse(df35, 'X1, N2, N3, N6')
analyse(df36, 'X1, N2, N3, N4, N7')















# Combining malicious and benign data for train/test

# X_train, y_train = 14,000 malicious + 10,000 benign (IPs) for training
# X_test, y_test = 1000 malicious + 22,000 benign (IPs) for testing






# print(df['target'].iloc[24437]) // end of mal
# print(df['target'].iloc[24439]) // begin of benign
# Out:
# Accuracy for:  X1
# RandomForestClassifier: 0.8107476635514018
# DecisionTreeClassifier: 0.8107476635514018
#
# Accuracy for:  X1, N2
# RandomForestClassifier: 0.8961578400830738
# DecisionTreeClassifier: 0.9006576670128073
#
# Accuracy for:  X1, N2, N3
# RandomForestClassifier: 0.8740048459674628
# DecisionTreeClassifier: 0.8837833160263067
#
# Accuracy for:  X1, N2, N3, N4
# RandomForestClassifier: 0.8650051921079959
# DecisionTreeClassifier: 0.8586881273797161
#
# Accuracy for:  X1, N2, N3, N4, N5
# RandomForestClassifier: 0.8750432675666321
# DecisionTreeClassifier: 0.8655244029075805
#
# Accuracy for:  X1, N2, N3, N4, N5, N6
# RandomForestClassifier: 0.8640533056420907
# DecisionTreeClassifier: 0.8576497057805469
#
# Accuracy for:  X1, N2, N3, N4, N5, N6, N7
# RandomForestClassifier: 0.8492557978539287
# DecisionTreeClassifier: 0.8496019383869852
#
# Accuracy for:  X1, X2
# RandomForestClassifier: 0.8963309103496019
# DecisionTreeClassifier: 0.9006576670128073
#
# Accuracy for:  X1, X2, X3
# RandomForestClassifier: 0.874177916233991
# DecisionTreeClassifier: 0.8830910349601938
#
# Accuracy for:  X1, X2, X3, X4
# RandomForestClassifier: 0.868380062305296
# DecisionTreeClassifier: 0.8590342679127726
#
# Accuracy for:  X1, X2, N2
# RandomForestClassifier: 0.8886292834890965
# DecisionTreeClassifier: 0.900484596746279
#
# Accuracy for:  X1, X2, N3
# RandomForestClassifier: 0.8680339217722395
# DecisionTreeClassifier: 0.8830044998269297
#
# Accuracy for:  X1, X2, N4
# RandomForestClassifier: 0.8505538248528903
# DecisionTreeClassifier: 0.8681204569055037
#
# Accuracy for:  X1, X2, N2, N3
# RandomForestClassifier: 0.8849082727587401
# DecisionTreeClassifier: 0.880754586362063
#
# Accuracy for:  X1, X2, N2, N3, N4
# RandomForestClassifier: 0.8727068189685012
# DecisionTreeClassifier: 0.8596400138456213
#
# Accuracy for:  X1, X2, X3, N2, N3
# RandomForestClassifier: 0.8761682242990654
# DecisionTreeClassifier: 0.8813603322949117
#
# Accuracy for:  N2
# RandomForestClassifier: 0.7361543786777431
# DecisionTreeClassifier: 0.734337140879197
#
# Accuracy for:  N2, N3
# RandomForestClassifier: 0.7647109726548978
# DecisionTreeClassifier: 0.765662859120803
#
# Accuracy for:  N2, N3, N4
# RandomForestClassifier: 0.7445482866043613
# DecisionTreeClassifier: 0.7413464866735895
#
# Accuracy for:  N2, N3, N4, N5
# RandomForestClassifier: 0.842938733125649
# DecisionTreeClassifier: 0.8324679820006923
#
# Accuracy for:  N2, N3, N4, N5, N6
# RandomForestClassifier: 0.8303046036690896
# DecisionTreeClassifier: 0.8233817930079612
#
# Accuracy for:  N3
# RandomForestClassifier: 0.6715126341294566
# DecisionTreeClassifier: 0.671858774662513
#
# Accuracy for:  N3, N4
# RandomForestClassifier: 0.6054863274489443
# DecisionTreeClassifier: 0.5989096573208723
#
# Accuracy for:  N3, N4, N5
# RandomForestClassifier: 0.740134994807892
# DecisionTreeClassifier: 0.7422983731394946
#
# Accuracy for:  N3, N4, N5, N6
# RandomForestClassifier: 0.7512114918656975
# DecisionTreeClassifier: 0.7446348217376255
#
# Accuracy for:  N5, N6
# RandomForestClassifier: 0.7628071997230875
# DecisionTreeClassifier: 0.764797507788162
#
# Accuracy for:  N4, N5, N6
# RandomForestClassifier: 0.7362409138110073
# DecisionTreeClassifier: 0.7400484596746278
#
# Accuracy for:  X1, X2, N5
# RandomForestClassifier: 0.8978885427483558
# DecisionTreeClassifier: 0.8989269643475251
#
# Accuracy for:  X1, X2, N6
# RandomForestClassifier: 0.8719280027691243
# DecisionTreeClassifier: 0.879110418830045
#
# Accuracy for:  X1, X2, N7
# RandomForestClassifier: 0.8503807545863621
# DecisionTreeClassifier: 0.8670820353063343
#
# Accuracy for:  X1, X2, X3, N6
# RandomForestClassifier: 0.8738317757009346
# DecisionTreeClassifier: 0.8714953271028038
#
# Accuracy for:  X1, X2, X3, X4, N7
# RandomForestClassifier: 0.8475250951886466
# DecisionTreeClassifier: 0.8516787815853236
#
# Accuracy for:  X1, N2, N5
# RandomForestClassifier: 0.8959847698165455
# DecisionTreeClassifier: 0.900484596746279
#
# Accuracy for:  X1, N2, N6
# RandomForestClassifier: 0.8736587054344064
# DecisionTreeClassifier: 0.8804084458290066
#
# Accuracy for:  X1, N2, N7
# RandomForestClassifier: 0.8521114572516442
# DecisionTreeClassifier: 0.8696780893042575
#
# Accuracy for:  X1, N2, N3, N6
# RandomForestClassifier: 0.877466251298027
# DecisionTreeClassifier: 0.8740913811007269
#
# Accuracy for:  X1, N2, N3, N4, N7
# RandomForestClassifier: 0.8502942194530979
# DecisionTreeClassifier: 0.8522845275181724
